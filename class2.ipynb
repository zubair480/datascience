# %%
import pandas as pd

data = {
    "calories": [420, 380, 390, 450],
    "duration": [30, 45, 40, 35]

}

df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        30
# 1       380        45
# 2       390        40
# 3       450        35

# %%
print(df.iloc[0,1])  # Access row by index label
# Out:
# 30
