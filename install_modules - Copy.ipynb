# %%
pip install numpy==2.1.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==2.1.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install urllib3==2.1.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting urllib3==2.1.0
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
# Installing collected packages: urllib3
# Successfully installed urllib3-2.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install datetime==5.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datetime==5.4
#   Downloading DateTime-5.4-py3-none-any.whl.metadata (33 kB)
# Collecting zope.interface (from datetime==5.4)
#   Downloading zope.interface-7.2-cp313-cp313-win_amd64.whl.metadata (45 kB)
# Requirement already satisfied: pytz in c:\users\zubai\appdata\roaming\python\python313\site-packages (from datetime==5.4) (2025.2)
# Collecting setuptools (from zope.interface->datetime==5.4)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading DateTime-5.4-py3-none-any.whl (52 kB)
# Downloading zope.interface-7.2-cp313-cp313-win_amd64.whl (212 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.0 MB/s eta 0:00:00
# Installing collected packages: setuptools, zope.interface, datetime
#
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ---------------------------------------- 0/3 [setuptools]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    ------------- -------------------------- 1/3 [zope.interface]
#    -------------------------- ------------- 2/3 [datetime]
#    ---------------------------------------- 3/3 [datetime]
#
# Successfully installed datetime-5.4 setuptools-80.9.0 zope.interface-7.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas==2.2.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas==2.2.3) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 11.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.5 MB 9.1 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.5 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.2
#     Uninstalling pandas-2.3.2:
#       Successfully uninstalled pandas-2.3.2
# Successfully installed pandas-2.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn==0.13.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn==0.13.2
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from seaborn==0.13.2) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from seaborn==0.13.2) (2.2.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn==0.13.2)
#   Downloading matplotlib-3.10.5-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (25.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.5-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------- ------------------------- 2.9/8.1 MB 14.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 14.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 13.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB 14.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/7.0 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 12.7 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [kiwisolver]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.5 pillow-11.3.0 pyparsing-3.2.3 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install geopandas==0.14.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopandas==0.14.3
#   Downloading geopandas-0.14.3-py3-none-any.whl.metadata (1.5 kB)
# Collecting fiona>=1.8.21 (from geopandas==0.14.3)
#   Downloading fiona-1.10.1-cp313-cp313-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: packaging in c:\users\zubai\appdata\roaming\python\python313\site-packages (from geopandas==0.14.3) (25.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from geopandas==0.14.3) (2.2.3)
# Collecting pyproj>=3.3.0 (from geopandas==0.14.3)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=1.8.0 (from geopandas==0.14.3)
#   Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting attrs>=19.2.0 (from fiona>=1.8.21->geopandas==0.14.3)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from fiona>=1.8.21->geopandas==0.14.3)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting click~=8.0 (from fiona>=1.8.21->geopandas==0.14.3)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas==0.14.3)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas==0.14.3)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: colorama in c:\users\zubai\appdata\roaming\python\python313\site-packages (from click~=8.0->fiona>=1.8.21->geopandas==0.14.3) (0.4.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->geopandas==0.14.3) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->geopandas==0.14.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->geopandas==0.14.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas>=1.4.0->geopandas==0.14.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas==0.14.3) (1.17.0)
# Downloading geopandas-0.14.3-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.4 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp313-cp313-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/24.5 MB 6.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.1/24.5 MB 7.3 MB/s eta 0:00:03
#    ------- -------------------------------- 4.7/24.5 MB 7.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.3/24.5 MB 7.5 MB/s eta 0:00:03
#    -------------- ------------------------- 8.7/24.5 MB 8.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.2/24.5 MB 8.5 MB/s eta 0:00:02
#    -------------------- ------------------- 12.3/24.5 MB 8.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.4/24.5 MB 8.4 MB/s eta 0:00:02
#    -------------------------- ------------- 16.3/24.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------------ --------- 18.4/24.5 MB 8.6 MB/s eta 0:00:01
#    --------------------------------- ------ 20.4/24.5 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 22.5/24.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 8.7 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.3 MB 12.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 11.4 MB/s eta 0:00:00
# Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.8 MB/s eta 0:00:00
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Installing collected packages: shapely, click, certifi, attrs, pyproj, cligj, click-plugins, fiona, geopandas
#
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---------------------------------------- 0/9 [shapely]
#    ---- ----------------------------------- 1/9 [click]
#    ---- ----------------------------------- 1/9 [click]
#    -------- ------------------------------- 2/9 [certifi]
#    ------------- -------------------------- 3/9 [attrs]
#    ------------- -------------------------- 3/9 [attrs]
#    ----------------- ---------------------- 4/9 [pyproj]
#    ----------------- ---------------------- 4/9 [pyproj]
#    ----------------- ---------------------- 4/9 [pyproj]
#    ----------------- ---------------------- 4/9 [pyproj]
#    ----------------- ---------------------- 4/9 [pyproj]
#    ---------------------- ----------------- 5/9 [cligj]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ------------------------------- -------- 7/9 [fiona]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ----------------------------------- ---- 8/9 [geopandas]
#    ---------------------------------------- 9/9 [geopandas]
#
# Successfully installed attrs-25.3.0 certifi-2025.8.3 click-8.2.1 click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1 geopandas-0.14.3 pyproj-3.7.2 shapely-2.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn==1.7.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn==1.7.1
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from scikit-learn==1.7.1) (2.1.0)
# Collecting scipy>=1.8.0 (from scikit-learn==1.7.1)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.7.1)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.7.1)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.7 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.7 MB 2.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/8.7 MB 2.5 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.7 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.7 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.4/8.7 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.7 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 4.2/8.7 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.7 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.7 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 5.2/8.7 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 6.0/8.7 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.7 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 6.6/8.7 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 7.1/8.7 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 1.8 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.5 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.3/38.5 MB 2.5 MB/s eta 0:00:15
#    - -------------------------------------- 1.6/38.5 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.8/38.5 MB 1.9 MB/s eta 0:00:20
#    -- ------------------------------------- 2.6/38.5 MB 2.2 MB/s eta 0:00:16
#    --- ------------------------------------ 3.7/38.5 MB 2.6 MB/s eta 0:00:14
#    ---- ----------------------------------- 3.9/38.5 MB 2.6 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.5/38.5 MB 2.5 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.0/38.5 MB 2.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.2/38.5 MB 2.5 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.8/38.5 MB 2.4 MB/s eta 0:00:14
#    ------ --------------------------------- 6.3/38.5 MB 2.4 MB/s eta 0:00:14
#    ------ --------------------------------- 6.6/38.5 MB 2.3 MB/s eta 0:00:14
#    ------- -------------------------------- 7.1/38.5 MB 2.3 MB/s eta 0:00:14
#    ------- -------------------------------- 7.6/38.5 MB 2.3 MB/s eta 0:00:14
#    -------- ------------------------------- 8.1/38.5 MB 2.3 MB/s eta 0:00:14
#    --------- ------------------------------ 8.9/38.5 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.4/38.5 MB 2.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 9.7/38.5 MB 2.4 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.0/38.5 MB 2.5 MB/s eta 0:00:11
#    ------------- -------------------------- 12.6/38.5 MB 2.8 MB/s eta 0:00:10
#    -------------- ------------------------- 13.9/38.5 MB 2.9 MB/s eta 0:00:09
#    --------------- ------------------------ 14.7/38.5 MB 3.0 MB/s eta 0:00:09
#    ---------------- ----------------------- 15.5/38.5 MB 3.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.5/38.5 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 17.3/38.5 MB 3.1 MB/s eta 0:00:07
#    ------------------- -------------------- 18.4/38.5 MB 3.2 MB/s eta 0:00:07
#    ------------------- -------------------- 19.1/38.5 MB 3.2 MB/s eta 0:00:07
#    -------------------- ------------------- 19.9/38.5 MB 3.2 MB/s eta 0:00:06
#    --------------------- ------------------ 20.7/38.5 MB 3.2 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.5/38.5 MB 3.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.3/38.5 MB 3.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.1/38.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------ --------------- 23.6/38.5 MB 3.2 MB/s eta 0:00:05
#    ------------------------- -------------- 24.1/38.5 MB 3.2 MB/s eta 0:00:05
#    ------------------------- -------------- 24.4/38.5 MB 3.1 MB/s eta 0:00:05
#    ------------------------- -------------- 24.6/38.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 25.2/38.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 25.4/38.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 26.0/38.5 MB 3.0 MB/s eta 0:00:05
#    --------------------------- ------------ 26.5/38.5 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/38.5 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.5 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/38.5 MB 2.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.3/38.5 MB 2.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.6/38.5 MB 2.9 MB/s eta 0:00:04
#    ------------------------------ --------- 29.1/38.5 MB 2.9 MB/s eta 0:00:04
#    ------------------------------ --------- 29.6/38.5 MB 2.9 MB/s eta 0:00:04
#    ------------------------------- -------- 30.4/38.5 MB 2.9 MB/s eta 0:00:03
#    -------------------------------- ------- 30.9/38.5 MB 2.9 MB/s eta 0:00:03
#    -------------------------------- ------- 31.2/38.5 MB 2.9 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/38.5 MB 2.8 MB/s eta 0:00:03
#    --------------------------------- ------ 32.0/38.5 MB 2.8 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/38.5 MB 2.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.0/38.5 MB 2.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.5 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 2.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyreadstat==1.3.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyreadstat==1.3.1
#   Downloading pyreadstat-1.3.1-cp313-cp313-win_amd64.whl.metadata (1.3 kB)
# Collecting narwhals>=2.0 (from pyreadstat==1.3.1)
#   Downloading narwhals-2.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pyreadstat==1.3.1) (2.1.0)
# Downloading pyreadstat-1.3.1-cp313-cp313-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 2.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.4 MB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.8/2.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.2 MB/s eta 0:00:00
# Downloading narwhals-2.2.0-py3-none-any.whl (401 kB)
# Installing collected packages: narwhals, pyreadstat
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 2/2 [pyreadstat]
#
# Successfully installed narwhals-2.2.0 pyreadstat-1.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyarrow==18.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyarrow==18.0.0
#   Downloading pyarrow-18.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Downloading pyarrow-18.0.0-cp313-cp313-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/25.1 MB 4.3 MB/s eta 0:00:06
#    -- ------------------------------------- 1.3/25.1 MB 4.9 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/25.1 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/25.1 MB 4.3 MB/s eta 0:00:06
#    ------ --------------------------------- 4.2/25.1 MB 4.3 MB/s eta 0:00:05
#    -------- ------------------------------- 5.2/25.1 MB 4.4 MB/s eta 0:00:05
#    --------- ------------------------------ 6.0/25.1 MB 4.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.3/25.1 MB 3.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.3/25.1 MB 4.0 MB/s eta 0:00:05
#    ------------- -------------------------- 8.4/25.1 MB 4.1 MB/s eta 0:00:05
#    --------------- ------------------------ 9.4/25.1 MB 4.3 MB/s eta 0:00:04
#    --------------- ------------------------ 10.0/25.1 MB 4.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.5/25.1 MB 3.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 11.3/25.1 MB 3.9 MB/s eta 0:00:04
#    ------------------ --------------------- 11.5/25.1 MB 3.9 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.1 MB 3.6 MB/s eta 0:00:04
#    ------------------- -------------------- 12.1/25.1 MB 3.5 MB/s eta 0:00:04
#    -------------------- ------------------- 12.6/25.1 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 13.1/25.1 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 13.6/25.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.4/25.1 MB 3.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.9/25.1 MB 3.3 MB/s eta 0:00:04
#    ------------------------- -------------- 15.7/25.1 MB 3.3 MB/s eta 0:00:03
#    ------------------------- -------------- 15.7/25.1 MB 3.3 MB/s eta 0:00:03
#    ------------------------- -------------- 16.0/25.1 MB 3.1 MB/s eta 0:00:03
#    -------------------------- ------------- 16.5/25.1 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.6/25.1 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.1/25.1 MB 3.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 18.6/25.1 MB 3.1 MB/s eta 0:00:03
#    ------------------------------ --------- 19.1/25.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 19.7/25.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 20.2/25.1 MB 3.0 MB/s eta 0:00:02
#    --------------------------------- ------ 21.0/25.1 MB 3.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.8/25.1 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.3/25.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.1 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.9/25.1 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 24.4/25.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  24.6/25.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 3.0 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-18.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install openpyxl==3.1.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl==3.1.2
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl==3.1.2)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install statsmodels==0.14.5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels==0.14.5
#   Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from statsmodels==0.14.5) (2.1.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from statsmodels==0.14.5) (1.16.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from statsmodels==0.14.5) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels==0.14.5)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from statsmodels==0.14.5) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.5) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\zubai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels==0.14.5) (1.17.0)
# Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 5.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.6 MB 6.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.6 MB 5.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.6 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.6 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.6 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.6 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 6.0/9.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.8 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.1 statsmodels-0.14.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
